# %%
import numpy as np
import pandas as pd
import seaborn as sns
from math import pi

# %%
teams = pd.read_csv('teams.csv')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(teams.common_name,teams.wins)
plt.xlabel('common_name')
plt.ylabel('wins')
plt.xticks(rotation=90)
plt.show()

# %%
ls
# Out:
# Aerialballswon_1819.csv                minutesplayed_1819.csv
# EPL stats 2018-19.ipynb                passesintercepted_1819.csv
# Top_10_DMs.csv                         players conceded goals.sql
# areialballslost_1819.csv               players.csv
# attempted_passes_1819.csv              players_conceded_goals.csv
# cleansheets_1819.csv                   players_defence
# clearences_1819.csv                    players_interceptionsvtackles
# clearencesleadingtopossesion_1819.csv  players_mv.csv
# completed_passes1819.csv               plmidfielders_mv.csv
# foulscommitted_1819.csv                successfultackles_1819.csv
# fpl_data_2018_2019.json                tackles_1819.csv
# league_matches.csv                     teams copy.csv
# league_stats.csv                       teams.csv

# %%
df = pd.read_csv('players_conceded_goals.csv', encoding='latin-1')

# %%
df
# Out:
#                                 full_name             Current_Club  \
# 0                           Mesut _zil                  Arsenal
# 1                      Henrikh Mkhitaryan                  Arsenal
# 2                            Aaron Ramsey                  Arsenal
# 3                            Granit Xhaka                  Arsenal
# 4                  Ainsley Maitland-Niles                  Arsenal
# ..                                    ...                      ...
# 139  H_Êlder Wander Sousa Azevedo Costa  Wolverhampton Wanderers
# 140                    Morgan Gibbs-White  Wolverhampton Wanderers
# 141                       Romain Sa_ªss  Wolverhampton Wanderers
# 142                Adama Traor_Ê Diarra  Wolverhampton Wanderers
# 143                    Leander Dendoncker  Wolverhampton Wanderers
#
#        position  minutes_played_overall  conceded_overall  \
# 0    Midfielder                    1741                23
# 1    Midfielder                    1643                25
# 2    Midfielder                    1327                12
# 3    Midfielder                    2502                35
# 4    Midfielder                     985                16
# ..          ...                     ...               ...
# 139  Midfielder                    1345                18
# 140  Midfielder                     647                 9
# 141  Midfielder                    1144                16
# 142  Midfielder                     890                11
# 143  Midfielder                    1469                19
#
#      conceded_per_90_overall  minutes_not_played  conceded_WO  \
# 0                       1.19                1679           28
# 1                       1.37                1777           26
# 2                       0.81                2093           39
# 3                       1.26                 918           16
# 4                       1.46                2435           35
# ..                       ...                 ...          ...
# 139                     1.20                2075           28
# 140                     1.25                2773           37
# 141                     1.26                2276           30
# 142                     1.11                2530           35
# 143                     1.16                1951           27
#
#      conceded_WO_per_90  conceded_per_90_diff
# 0                  1.50                  0.31
# 1                  1.32                 -0.05
# 2                  1.68                  0.87
# 3                  1.57                  0.31
# 4                  1.29                 -0.17
# ..                  ...                   ...
# 139                1.21                  0.01
# 140                1.20                 -0.05
# 141                1.19                 -0.07
# 142                1.25                  0.14
# 143                1.25                  0.09
#
# [144 rows x 10 columns]

# %%
df.iloc[3:7]
# Out:
#                      full_name Current_Club    position  \
# 3                 Granit Xhaka      Arsenal  Midfielder
# 4       Ainsley Maitland-Niles      Arsenal  Midfielder
# 5  Matt_Êo Guendouzi Oli_Ê      Arsenal  Midfielder
# 6               Lucas Torreira      Arsenal  Midfielder
#
#    minutes_played_overall  conceded_overall  conceded_per_90_overall  \
# 3                    2502                35                     1.26
# 4                     985                16                     1.46
# 5                    2143                28                     1.18
# 6                    2377                35                     1.33
#
#    minutes_not_played  conceded_WO  conceded_WO_per_90  conceded_per_90_diff
# 3                 918           16                1.57                  0.31
# 4                2435           35                1.29                 -0.17
# 5                1277           23                1.62                  0.44
# 6                1043           16                1.38                  0.05

# %%
for index, row in df.iterrows():
    print(index,row['full_name'])
# Out:
# 0 Mesut _zil
# 1 Henrikh Mkhitaryan
# 2 Aaron Ramsey
# 3 Granit Xhaka
# 4 Ainsley Maitland-Niles
# 5 Matt_Êo Guendouzi Oli_Ê
# 6 Lucas Torreira
# 7 Moussa Sissoko
# 8 Christian Eriksen
# 9 Lucas Rodrigues Moura da Silva
# 10 Dele Alli
# 11 Eric Dier
# 12 Moussa Dembele
# 13 Erik Lamela
# 14 Harry Winks
# 15 Victor Wanyama
# 16 Fernando Luiz Rosa
# 17 åÛãlkay G__ndoåÛ¨an
# 18 Riyad Mahrez
# 19 Bernardo Silva
# 20 Kevin De Bruyne
# 21 Leroy San_Ê
# 22 David Silva
# 23 Fabian Delph
# 24 Oleksandr Zinchenko
# 25 Daniel Amartey
# 26 Onyinye Wilfred Ndidi
# 27 Demarai Gray
# 28 James Maddison
# 29 Marc Albrighton
# 30 Nampalys Mendy
# 31 Hamza Choudhury
# 32 Harvey Lewis Barnes
# 33 Youri Tielemans
# 34 Aaron Wan-Bissaka
# 35 James McArthur
# 36 Andros Townsend
# 37 Wilfried Zaha
# 38 Cheikhou Kouyat_Ê
# 39 Max Meyer
# 40 Morgan Schneiderlin
# 41 Gylfi Sigurdsson
# 42 Idrissa Gana Gueye
# 43 Tom Davies
# 44 Bernard An__cio Caldeira Duarte
# 45 Andr_Ê Filipe Tavares Gomes
# 46 Aaron Lennon
# 47 Jack Cork
# 48 Johann Berg Gu_ãmunds¼_son
# 49 Ashley Westwood
# 50 Jeff Hendrick
# 51 Robbie Brady
# 52 Oriol Romeu
# 53 Stuart Armstrong
# 54 Nathan Redmond
# 55 Mario Lemina
# 56 Mohamed Elyounoussi
# 57 James Ward-Prowse
# 58 Pierre-Emile H_Ì_jbjerg
# 59 Andrew Surman
# 60 Dan Gosling
# 61 Ryan Fraser
# 62 Jordon Ibe
# 63 Lewis Cook
# 64 Jefferson Lerma
# 65 Junior Stanislas
# 66 Juan Mata
# 67 Paul Pogba
# 68 Frederico Rodrigues Santos
# 69 Andreas Pereira
# 70 Scott McTominay
# 71 Marouane Fellaini
# 72 Ashley Young
# 73 Jesse Lingard
# 74 Ander Herrera
# 75 Nemanja MatiåÛ¥
# 76 James Milner
# 77 Georginio Wijnaldum
# 78 Naby Deco Ke_ªta
# 79 Jordan Henderson
# 80 Xherdan Shaqiri
# 81 Fabinho
# 82 Ross Barkley
# 83 Jorginho
# 84 N'Golo Kant_Ê
# 85 Pedro Rodriguez
# 86 Ruben Loftus-Cheek
# 87 Eden Hazard
# 88 Mateo KovaåÛåiåÛ¥
# 89 Ryan Fredericks
# 90 Mark Noble
# 91 Michail Antonio
# 92 Felipe Anderson Pereira Gomes
# 93 Declan Rice
# 94 Robert Snodgrass
# 95 Pedro Obiang
# 96 Grady Diangana
# 97 Manuel Lanzini
# 98 Etienne Capoue
# 99 Abdoulaye Doucour_Ê
# 100 Will Hughes
# 101 Ken Sema
# 102 Francisco Femen__a Far
# 103 Jonjo Shelvey
# 104 Mohamed Diam_Ê
# 105 Matt Ritchie
# 106 Robert Kenedy Nunes do Nascimento
# 107 Christian Atsu Twasam
# 108 Sung-Yeung Ki
# 109 Isaac Hayden
# 110 Sean Longstaff
# 111 Miguel _ångel Almir__n Rejala
# 112 Bobby Reid
# 113 Joe Ralls
# 114 Nathaniel Mendez-Laing
# 115 V__ctor Camarasa
# 116 Harry Arter
# 117 Aron Einar Gunnarsson
# 118 Leandro Bacuna
# 119 Kevin McDonald
# 120 Andr_Ê Sch__rrle
# 121 Tom Cairney
# 122 Jean Micha_Ìàl Seri
# 123 Andr_Ê-Frank Zambo Anguissa
# 124 Dale Stephens
# 125 Pascal Gro_¨
# 126 Davy Pr__pper
# 127 Anthony Knockaert
# 128 Solomon March
# 129 Yves Bissouma
# 130 Beram Kayal
# 131 Jonathan Hogg
# 132 Aaron Mooy
# 133 Alex Pritchard
# 134 Philip Billing
# 135 Juninho Bacuna
# 136 Jo_o Moutinho
# 137 R_¼ben Diogo Da Silva Neves
# 138 Diogo Jos_Ê Teixeira da Silva
# 139 H_Êlder Wander Sousa Azevedo Costa
# 140 Morgan Gibbs-White
# 141 Romain Sa_ªss
# 142 Adama Traor_Ê Diarra
# 143 Leander Dendoncker

# %%
df.loc[df['Current_Club'] == 'West Ham United']
# Out:
#                         full_name     Current_Club    position  \
# 89                Ryan Fredericks  West Ham United  Midfielder
# 90                     Mark Noble  West Ham United  Midfielder
# 91                Michail Antonio  West Ham United  Midfielder
# 92  Felipe Anderson Pereira Gomes  West Ham United  Midfielder
# 93                    Declan Rice  West Ham United  Midfielder
# 94               Robert Snodgrass  West Ham United  Midfielder
# 95                   Pedro Obiang  West Ham United  Midfielder
# 96                 Grady Diangana  West Ham United  Midfielder
# 97                 Manuel Lanzini  West Ham United  Midfielder
#
#     minutes_played_overall  conceded_overall  conceded_per_90_overall  \
# 89                    1085                13                     1.08
# 90                    2308                29                     1.13
# 91                    2099                26                     1.11
# 92                    3054                43                     1.27
# 93                    3005                42                     1.26
# 94                    2222                31                     1.26
# 95                    1121                17                     1.36
# 96                     604                11                     1.64
# 97                     688                11                     1.44
#
#     minutes_not_played  conceded_WO  conceded_WO_per_90  conceded_per_90_diff
# 89                2335           42                1.62                  0.54
# 90                1112           26                2.10                  0.97
# 91                1321           29                1.98                  0.87
# 92                 366           12                2.95                  1.68
# 93                 415           13                2.82                  1.56
# 94                1198           24                1.80                  0.54
# 95                2299           38                1.49                  0.13
# 96                2816           44                1.41                 -0.23
# 97                2732           44                1.45                  0.01

# %%
df['Total_conceded'] = df['conceded_overall']+df['conceded_WO']

# %%
df
# Out:
#                                 full_name             Current_Club  \
# 0                           Mesut _zil                  Arsenal
# 1                      Henrikh Mkhitaryan                  Arsenal
# 2                            Aaron Ramsey                  Arsenal
# 3                            Granit Xhaka                  Arsenal
# 4                  Ainsley Maitland-Niles                  Arsenal
# ..                                    ...                      ...
# 139  H_Êlder Wander Sousa Azevedo Costa  Wolverhampton Wanderers
# 140                    Morgan Gibbs-White  Wolverhampton Wanderers
# 141                       Romain Sa_ªss  Wolverhampton Wanderers
# 142                Adama Traor_Ê Diarra  Wolverhampton Wanderers
# 143                    Leander Dendoncker  Wolverhampton Wanderers
#
#        position  minutes_played_overall  conceded_overall  \
# 0    Midfielder                    1741                23
# 1    Midfielder                    1643                25
# 2    Midfielder                    1327                12
# 3    Midfielder                    2502                35
# 4    Midfielder                     985                16
# ..          ...                     ...               ...
# 139  Midfielder                    1345                18
# 140  Midfielder                     647                 9
# 141  Midfielder                    1144                16
# 142  Midfielder                     890                11
# 143  Midfielder                    1469                19
#
#      conceded_per_90_overall  minutes_not_played  conceded_WO  \
# 0                       1.19                1679           28
# 1                       1.37                1777           26
# 2                       0.81                2093           39
# 3                       1.26                 918           16
# 4                       1.46                2435           35
# ..                       ...                 ...          ...
# 139                     1.20                2075           28
# 140                     1.25                2773           37
# 141                     1.26                2276           30
# 142                     1.11                2530           35
# 143                     1.16                1951           27
#
#      conceded_WO_per_90  conceded_per_90_diff  Total_conceded
# 0                  1.50                  0.31              51
# 1                  1.32                 -0.05              51
# 2                  1.68                  0.87              51
# 3                  1.57                  0.31              51
# 4                  1.29                 -0.17              51
# ..                  ...                   ...             ...
# 139                1.21                  0.01              46
# 140                1.20                 -0.05              46
# 141                1.19                 -0.07              46
# 142                1.25                  0.14              46
# 143                1.25                  0.09              46
#
# [144 rows x 11 columns]

# %%
df.groupby(['Current_Club']).count()
# Out:
#                          full_name  position  minutes_played_overall  \
# Current_Club
# AFC Bournemouth                  7         7                       7
# Arsenal                          7         7                       7
# Brighton & Hove Albion           7         7                       7
# Burnley                          6         6                       6
# Cardiff City                     7         7                       7
# Chelsea                          7         7                       7
# Crystal Palace                   6         6                       6
# Everton                          6         6                       6
# Fulham                           5         5                       5
# Huddersfield Town                5         5                       5
# Leicester City                   9         9                       9
# Liverpool                        6         6                       6
# Manchester City                  9         9                       9
# Manchester United               10        10                      10
# Newcastle United                 9         9                       9
# Southampton                      7         7                       7
# Tottenham Hotspur                9         9                       9
# Watford                          5         5                       5
# West Ham United                  9         9                       9
# Wolverhampton Wanderers          8         8                       8
#
#                          conceded_overall  conceded_per_90_overall  \
# Current_Club
# AFC Bournemouth                         7                        7
# Arsenal                                 7                        7
# Brighton & Hove Albion                  7                        7
# Burnley                                 6                        6
# Cardiff City                            7                        7
# Chelsea                                 7                        7
# Crystal Palace                          6                        6
# Everton                                 6                        6
# Fulham                                  5                        5
# Huddersfield Town                       5                        5
# Leicester City                          9                        9
# Liverpool                               6                        6
# Manchester City                         9                        9
# Manchester United                      10                       10
# Newcastle United                        9                        9
# Southampton                             7                        7
# Tottenham Hotspur                       9                        9
# Watford                                 5                        5
# West Ham United                         9                        9
# Wolverhampton Wanderers                 8                        8
#
#                          minutes_not_played  conceded_WO  conceded_WO_per_90  \
# Current_Club
# AFC Bournemouth                           7            7                   7
# Arsenal                                   7            7                   7
# Brighton & Hove Albion                    7            7                   7
# Burnley                                   6            6                   6
# Cardiff City                              7            7                   7
# Chelsea                                   7            7                   7
# Crystal Palace                            6            6                   6
# Everton                                   6            6                   6
# Fulham                                    5            5                   5
# Huddersfield Town                         5            5                   5
# Leicester City                            9            9                   9
# Liverpool                                 6            6                   6
# Manchester City                           9            9                   9
# Manchester United                        10           10                  10
# Newcastle United                          9            9                   9
# Southampton                               7            7                   7
# Tottenham Hotspur                         9            9                   9
# Watford                                   5            5                   5
# West Ham United                           9            9                   9
# Wolverhampton Wanderers                   8            8                   8
#
#                          conceded_per_90_diff  Total_conceded
# Current_Club
# AFC Bournemouth                             7               7
# Arsenal                                     7               7
# Brighton & Hove Albion                      7               7
# Burnley                                     6               6
# Cardiff City                                7               7
# Chelsea                                     7               7
# Crystal Palace                              6               6
# Everton                                     6               6
# Fulham                                      5               5
# Huddersfield Town                           5               5
# Leicester City                              9               9
# Liverpool                                   6               6
# Manchester City                             9               9
# Manchester United                          10              10
# Newcastle United                            9               9
# Southampton                                 7               7
# Tottenham Hotspur                           9               9
# Watford                                     5               5
# West Ham United                             9               9
# Wolverhampton Wanderers                     8               8

# %%
plt.figure(figsize=(5,3), dpi=200)
plt.plot([0,1,2,3,4],[10,8,6,4,2], label='a', color='r', linewidth = '2', linestyle = '--', marker = '.', markersize = '10', markeredgecolor = 'b')
x2 = np.arange(0,6,0.5)
plt.plot(x2[:6],x2[:6]**2, label = 'b')
plt.plot(x2[5:],x2[5:]**2, linestyle = '--')
plt.title('First Graph')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend()
plt.show()

# %%
pcg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-22bfc4d5a735> in <module>
# ----> 1 pcg
#
# NameError: name 'pcg' is not defined

# %%
bins = [-1,-0.5,0,0.5,1,1.5,2,2.5,3]
plt.hist(df.conceded_per_90_diff, bins=bins)
plt.xticks(bins)
plt.title('The difference in goals conceded when ON vs OFF the field')
plt.xlabel('conceded goals per 90 difference')
plt.ylabel('number of players')
plt.show()

# %%
WestHam = df.loc[df['Current_Club'] == 'West Ham United'].count()[0]
Arsenal = df.loc[df['Current_Club'] == 'Arsenal'].count()[0]
Labels = ['West Ham', 'Arsenal']

plt.pie([WestHam, Arsenal], labels=Labels, autopct='%.2f%%')
plt.show()

# %%
players = pd.read_csv('players.csv', encoding='latin-1')

# %%
players
# Out:
#                     full_name  age          league     season    position  \
# 0                David de Gea   29  Premier League  2018/2019  Goalkeeper
# 1              Matteo Darmian   30  Premier League  2018/2019    Defender
# 2    Victor Nilsson LindelÍ_f   25  Premier League  2018/2019    Defender
# 3                   Luke Shaw   24  Premier League  2018/2019    Defender
# 4        Eric Bertrand Bailly   25  Premier League  2018/2019    Defender
# ..                        ...  ...             ...        ...         ...
# 567              Matt Butcher   22  Premier League  2018/2019  Midfielder
# 568          Luca de la Torre   21  Premier League  2018/2019  Midfielder
# 569                Lewis Cass   20  Premier League  2018/2019    Defender
# 570             Kelland Watts   20  Premier League  2018/2019  Midfielder
# 571                Marc Guehi   19  Premier League  2018/2019    Defender
#
#           Current_Club  minutes_played_overall  minutes_played_home  \
# 0    Manchester United                    3420                 1710
# 1    Manchester United                     443                  353
# 2    Manchester United                    2602                 1112
# 3    Manchester United                    2592                 1170
# 4    Manchester United                     637                  349
# ..                 ...                     ...                  ...
# 567    AFC Bournemouth                       0                    0
# 568             Fulham                       0                    0
# 569   Newcastle United                       0                    0
# 570   Newcastle United                       0                    0
# 571            Chelsea                       0                    0
#
#      minutes_played_away     nationality  ...  conceded_per_90_overall  \
# 0                   1710           Spain  ...                     1.34
# 1                     90           Italy  ...                     1.42
# 2                   1490          Sweden  ...                     1.31
# 3                   1422         England  ...                     1.25
# 4                    288  CÍte d'Ivoire  ...                     1.70
# ..                   ...             ...  ...                      ...
# 567                    0         England  ...                     0.00
# 568                    0             USA  ...                     0.00
# 569                    0         England  ...                     0.00
# 570                    0         England  ...                     0.00
# 571                    0         England  ...                     0.00
#
#      min_per_conceded_overall  min_per_match  min_per_card_overall  \
# 0                          67             90                  3420
# 1                          63             74                     0
# 2                          68             87                  2602
# 3                          72             89                   236
# 4                          53             53                   319
# ..                        ...            ...                   ...
# 567                         0              0                     0
# 568                         0              0                     0
# 569                         0              0                     0
# 570                         0              0                     0
# 571                         0              0                     0
#
#      min_per_assist_overall  cards_per_90_overall  \
# 0                         0                  0.03
# 1                         0                  0.00
# 2                      2602                  0.03
# 3                       648                  0.38
# 4                         0                  0.28
# ..                      ...                   ...
# 567                       0                  0.00
# 568                       0                  0.00
# 569                       0                  0.00
# 570                       0                  0.00
# 571                       0                  0.00
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 0                             310                             419
# 1                             411                             366
# 2                             263                             249
# 3                             262                             104
# 4                             340                             271
# ..                            ...                             ...
# 567                            -1                              -1
# 568                            -1                              -1
# 569                            -1                              -1
# 570                            -1                              -1
# 571                            -1                              -1
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 0                              90                       18
# 1                             102                       25
# 2                              88                       14
# 3                              79                       13
# 4                             142                       26
# ..                            ...                      ...
# 567                            -1                       -1
# 568                            -1                       -1
# 569                            -1                       -1
# 570                            -1                       -1
# 571                            -1                       -1
#
# [572 rows x 45 columns]

# %%
plt.style.use('seaborn-bright')
youth = players.loc[players.age < 20].count()[0]
young = players.loc[(players.age < 23) & (19 < players.age)].count()[0]
middle_age = players.loc[(players.age < 31) & (22< players.age)].count()[0]
old = players.loc[30 < players.age].count()[0]

age = [youth,young,middle_age,old]
labels = ['<22','21<x<25','24<x<31','30<']
explode= [.1,.05,.0,.05]
plt.title('Age of players in the EPL')
plt.pie(age, labels=labels, autopct='%.2f%%', explode=explode, pctdistance=0.7)

plt.show()

# %%
plt.style.use('seaborn-bright')
plt.figure(figsize=(5,8))

Westham = players.loc[players.Current_Club == 'West Ham United']['age']
Arsenal = players.loc[players.Current_Club == 'Arsenal']['age']

labels=['West Ham','Arsenal']

plt.title('Age of players in EPL teams')
plt.xlabel('EPL team')
plt.ylabel('Age')
plt.yticks()
boxes = plt.boxplot([Westham,Arsenal], labels=labels, patch_artist=True, medianprops={'linewidth':2})
for box in boxes['boxes']:
    box.set(color='red', facecolor='blue')
plt.show()

# %%
ls
# Out:
# Aerialballswon_1819.csv                league_stats.csv
# EPL stats 2018-19.ipynb                minutesplayed_1819.csv
# Top_10_DMs.csv                         passesintercepted_1819.csv
# Top_30_DMs                             players conceded goals.sql
# Top_30_DMs.csv                         players.csv
# areialballslost_1819.csv               players_conceded_goals.csv
# attempted_passes_1819.csv              players_defence
# cleansheets_1819.csv                   players_interceptionsvtackles
# clearences_1819.csv                    players_mv.csv
# clearencesleadingtopossesion_1819.csv  plmidfielders_mv.csv
# completed_passes1819.csv               successfultackles_1819.csv
# foulscommitted_1819.csv                tackles_1819.csv
# fpl_data_2018_2019.json                teams copy.csv
# league_matches.csv                     teams.csv

# %%
top_30 = pd.read_csv('Top_30_DMs.csv', encoding='latin-1')

top_30
# Out:
#                 full_name             Current_Club  age    position  \
# 0           Onyinye Ndidi           Leicester City   24  Midfielder
# 1             Declan Rice          West Ham United   22  Midfielder
# 2          Philip Billing        Huddersfield Town   24  Midfielder
# 3         Jefferson Lerma          AFC Bournemouth   26  Midfielder
# 4          A. Z. Anguissa                   Fulham   25  Midfielder
# 5           Solomon March   Brighton & Hove Albion   26  Midfielder
# 6         Victor Camarasa             Cardiff City   26  Midfielder
# 7        Matteo Guendouzi                  Arsenal   21  Midfielder
# 8      Ruben Loftus-Cheek                  Chelsea   25  Midfielder
# 9               Dele Alli        Tottenham Hotspur   24  Midfielder
# 10            Will Hughes                  Watford   25  Midfielder
# 11             Diogo Jota  Wolverhampton Wanderers   24  Midfielder
# 12              Max Meyer           Crystal Palace   25  Midfielder
# 13        Youri Tielemans           Leicester City   23  Midfielder
# 14             Naby Keita                Liverpool   26  Midfielder
# 15            Harry Winks        Tottenham Hotspur   25  Midfielder
# 16           Demarai Gray           Leicester City   24  Midfielder
# 17          Mateo Kovacic                  Chelsea   26  Midfielder
# 18          Robert Kenedy         Newcastle United   25  Midfielder
# 19         James Maddison           Leicester City   24  Midfielder
# 20           Isaac Hayden         Newcastle United   25  Midfielder
# 21          Yves Bissouma   Brighton & Hove Albion   24  Midfielder
# 22            Ruben Neves  Wolverhampton Wanderers   24  Midfielder
# 23      James Ward-Prowse              Southampton   26  Midfielder
# 24  Pierre-Emile Hojbjerg              Southampton   25  Midfielder
#
#     minutes_played_overall  conceded_overall  conceded_per_90_overall  \
# 0                     3299                42                     1.15
# 1                     3005                42                     1.26
# 2                     2192                41                     1.68
# 3                     2511                45                     1.61
# 4                     1518                30                     1.78
# 5                     2473                39                     1.42
# 6                     2579                48                     1.68
# 7                     2143                28                     1.18
# 8                      983                 8                     0.73
# 9                     1827                17                     0.84
# 10                    2436                39                     1.44
# 11                    2371                29                     1.10
# 12                    1414                19                     1.21
# 13                    1092                13                     1.07
# 14                    1392                 7                     0.45
# 15                    1591                16                     0.91
# 16                    1992                26                     1.17
# 17                    1743                18                     0.93
# 18                    1344                17                     1.14
# 19                    2850                39                     1.23
# 20                    1886                25                     1.19
# 21                    1769                30                     1.53
# 22                    3009                40                     1.20
# 23                    1942                36                     1.67
# 24                    2764                52                     1.69
#
#     minutes_not_played  conceded_WO  conceded_WO_per_90  conceded_per_90_diff
# 0                  121            6                4.46                  3.31
# 1                  415           13                2.82                  1.56
# 2                 1228           35                2.57                  0.89
# 3                  909           25                2.48                  0.87
# 4                 1902           51                2.41                  0.63
# 5                  947           21                2.00                  0.58
# 6                  841           21                2.25                  0.57
# 7                 1277           23                1.62                  0.44
# 8                 2437           31                1.14                  0.41
# 9                 1593           22                1.24                  0.40
# 10                 984           20                1.83                  0.39
# 11                1049           17                1.46                  0.36
# 12                2006           34                1.53                  0.32
# 13                2328           35                1.35                  0.28
# 14                2028           15                0.67                  0.22
# 15                1829           23                1.13                  0.22
# 16                1428           22                1.39                  0.22
# 17                1677           21                1.13                  0.20
# 18                2076           31                1.34                  0.20
# 19                 570            9                1.42                  0.19
# 20                1534           23                1.35                  0.16
# 21                1651           30                1.64                  0.11
# 22                 411            6                1.31                  0.11
# 23                1478           29                1.77                  0.10
# 24                 656           13                1.78                  0.09

# %%
# Bar Graph (Decrease in goals conceded when player is on the pitch (per 90 mins))

plt.figure(figsize=(20,7))
           
sns.barplot(top_30.full_name, top_30.conceded_per_90_diff)
plt.title('Decrease in goals conceded when player is on the pitch, per 90 mins (Top 25)', fontsize=28)
plt.ylabel('Conceded without player per 90 - Conceded with player per 90')
plt.xlabel('Player name')
plt.xticks(rotation=50)

plt.show()

# %%
ls
# Out:
# Aerialballswon_1819.csv                minutesplayed_1819.csv
# EPL stats 2018-19.ipynb                passesintercepted_1819.csv
# Top_10_DMs.csv                         players conceded goals.sql
# Top_30_DMs                             players.csv
# Top_30_DMs.csv                         players_conceded_goals.csv
# areialballslost_1819.csv               players_defence
# attempted_passes_1819.csv              players_interceptionsvtackles
# cleansheets_1819.csv                   players_interceptionsvtackles.csv
# clearences_1819.csv                    players_mv.csv
# clearencesleadingtopossesion_1819.csv  plmidfielders_mv.csv
# completed_passes1819.csv               successfultackles_1819.csv
# foulscommitted_1819.csv                tackles_1819.csv
# fpl_data_2018_2019.json                teams copy.csv
# league_matches.csv                     teams.csv
# league_stats.csv

# %%
ivt = pd.read_csv('players_interceptionsvtackles.csv')

ivt.head(10)
# Out:
#            player  minutes_played  passes_intercepted  Successful_tackles  \
# 0   Idrissa Gueye            2825                  75                  89
# 1   Onyinye Ndidi            3298                  83                  99
# 2        Bernardo            1750                  34                  43
# 3       I. Hayden            1864                  40                  43
# 4   Dale Stephens            2487                  46                  57
# 5     Oriol Romeu            2139                  52                  46
# 6      Yan Valery            1714                  22                  36
# 7    Mario Lemina            1614                  43                  33
# 8  Philip Billing            2190                  53                  44
# 9            Rice            3004                  52                  60
#
#    passes_intercepted_per90  successful_tackles_per90
# 0                      2.39                      2.84
# 1                      2.27                      2.70
# 2                      1.75                      2.21
# 3                      1.93                      2.08
# 4                      1.66                      2.06
# 5                      2.19                      1.94
# 6                      1.16                      1.89
# 7                      2.40                      1.84
# 8                      2.18                      1.81
# 9                      1.56                      1.80

# %%
# Scatter Graph: Obtain possession(Successful Tackles v interceptions)

plt.figure(figsize=(20,20))

pip90 = ivt.passes_intercepted_per90
stp90 = ivt.successful_tackles_per90
plr = ivt.player

plt.scatter(pip90, stp90, c=stp90)
plt.title('Retrieving Possession (Top 50 from Successful tackles per 90)', fontsize=28)
plt.xlabel('Passes Intercepted per 90', fontsize=12)
plt.ylabel('Successful Tackles per 90', fontsize=12)

# labels for points

for i, txt in enumerate(plr):
    plt.annotate(txt, (pip90[i], stp90[i]),
                textcoords="offset points", # how to position the label
                xytext=(0,10), # distance from label to points (x,y)
                size=12, # size of label
                ha='center') # horizontal alignment can be left, right or center

plt.show()

# %%
rp = pd.read_csv('retain_poss_stats.csv')

# %%
rp.head(1)
# Out:
#             player  minutes_played  attempted_passes  \
# 0  Jorginho Frello            3165            3119.0
#
#    Clearances_leading_to_possession  Completed_passes  \
# 0                              35.0              2782
#
#    successful_pass_percentage  Clearences_leading_to_possession_per90
# 0                       0.892                                  0.9953

# %%
rpm = rp.drop(index=[1,2,3,4,5,6,7,8,15,18,27,32,33,34,37,39,42,43,44,47,49]).head(30)
rpmi = rpm.reset_index()
rpmi
# Out:
#     index            player  minutes_played  attempted_passes  \
# 0       0   Jorginho Frello            3165            3119.0
# 1       9             Xhaka            2501            2245.0
# 2      10          GŮndogan            2135               NaN
# 3      11       Fernandinho            2381            2050.0
# 4      12             Kante            3095            2021.0
# 5      13       David Silva            2409            2015.0
# 6      14             Pogba            3009            2068.0
# 7      16          Doucour_            3062               NaN
# 8      17         Wijnaldum            2736            1769.0
# 9      19             Matic            2440            1836.0
# 10     20       Milivojevic            3420            1986.0
# 11     21     Onyinye Ndidi            3298            1984.0
# 12     22          Moutinho            3038            1863.0
# 13     23       Ruben Neves            3009            1940.0
# 14     24            Hazard            2925            1819.0
# 15     25         Henderson            1982            1740.0
# 16     26           Eriksen            2771            1872.0
# 17     28          Hojbjerg            2764            1793.0
# 18     29            Capoue            2946            1749.0
# 19     30    Bernardo Silva            2853            1706.0
# 20     31     Idrissa Gueye            2825            1739.0
# 21     35  Matteo Guendouzi            2142            1597.0
# 22     36    Lucas Torreira            2379            1590.0
# 23     38         Jean Seri            2250            1592.0
# 24     40           Fabinho            2012            1610.0
# 25     41           Kovacic            1744            1468.0
# 26     45       Declan Rice            3004            1518.0
# 27     46   Jefferson Lerma            2510            1562.0
# 28     48             Noble            2308            1507.0
# 29     50     Jonathan Hogg            2375            1545.0
#
#     Clearances_leading_to_possession  Completed_passes  \
# 0                               35.0              2782
# 1                               54.0              1916
# 2                               18.0              1811
# 3                               69.0              1793
# 4                               26.0              1776
# 5                               13.0              1770
# 6                               36.0              1713
# 7                               54.0              1619
# 8                               24.0              1611
# 9                               52.0              1596
# 10                              66.0              1589
# 11                              80.0              1585
# 12                              40.0              1580
# 13                              44.0              1576
# 14                               4.0              1534
# 15                              13.0              1518
# 16                               7.0              1517
# 17                              28.0              1486
# 18                              91.0              1476
# 19                              24.0              1469
# 20                              44.0              1467
# 21                              24.0              1402
# 22                              31.0              1390
# 23                              14.0              1385
# 24                              26.0              1374
# 25                              18.0              1351
# 26                              54.0              1312
# 27                              84.0              1299
# 28                              12.0              1287
# 29                              18.0              1286
#
#     successful_pass_percentage  Clearences_leading_to_possession_per90
# 0                       0.8920                                  0.9953
# 1                       0.8535                                  1.9432
# 2                          NaN                                  0.7588
# 3                       0.8746                                  2.6081
# 4                       0.8788                                  0.7561
# 5                       0.8784                                  0.4857
# 6                       0.8283                                  1.0768
# 7                          NaN                                  1.5872
# 8                       0.9107                                  0.7895
# 9                       0.8693                                  1.9180
# 10                      0.8001                                  1.7368
# 11                      0.7989                                  2.1831
# 12                      0.8481                                  1.1850
# 13                      0.8124                                  1.3161
# 14                      0.8433                                  0.1231
# 15                      0.8724                                  0.5903
# 16                      0.8104                                  0.2274
# 17                      0.8288                                  0.9117
# 18                      0.8439                                  2.7800
# 19                      0.8611                                  0.7571
# 20                      0.8436                                  1.4018
# 21                      0.8779                                  1.0084
# 22                      0.8742                                  1.1728
# 23                      0.8700                                  0.5600
# 24                      0.8534                                  1.1630
# 25                      0.9203                                  0.9289
# 26                      0.8643                                  1.6178
# 27                      0.8316                                  3.0120
# 28                      0.8540                                  0.4679
# 29                      0.8324                                  0.6821

# %%
# Scatter Graph: Retain possession (Successful pass rate v clearences to possesion per 90)

plt.figure(figsize=(20,20))

spp = rpmi.successful_pass_percentage
ctp = rpmi.Clearences_leading_to_possession_per90
plr = rpmi.player

plt.scatter(spp, ctp, c=ctp)
plt.title('Retaining Possession (Top 30 from Successful pass%)', fontsize=28)
plt.xlabel('Successful passes %', fontsize=12)
plt.ylabel('Clearences leading to possession per 90', fontsize=12)

# labels for points

for i, txt in enumerate(plr):
    plt.annotate(txt, (spp[i], ctp[i]),
                textcoords="offset points", # how to position the label
                xytext=(0,10), # distance from label to points (x,y)
                size=12, # size of label
                ha='center') # horizontal alignment can be left, right or center

plt.show()

# %%
kc = pd.read_csv('key_candidates2.csv')
kc
# Out:
#                      player  successful_pass_percentage  \
# 0             Idrissa Gueye                        2.53
# 1             Onyinye Ndidi                        2.40
# 2               Wan-Bissaka                        2.19
# 3    Nathaniel Mendez-Laing                        1.86
# 4                  Bernardo                        2.18
# ..                      ...                         ...
# 277                 Alisson                        2.41
# 278             Sergio Rico                        1.62
# 279              Schmeichel                        1.96
# 280          Neil Etheridge                        0.97
# 281            Arrizabalaga                        2.56
#
#      passes_intercepted_per90  successful_tackles_per90  \
# 0                        2.39                      2.84
# 1                        2.27                      2.70
# 2                        2.41                      2.58
# 3                        1.19                      2.28
# 4                        1.75                      2.21
# ..                        ...                       ...
# 277                      0.03                      0.03
# 278                      0.03                      0.03
# 279                      0.08                      0.03
# 280                      0.18                      0.03
# 281                       NaN                      0.03
#
#      aerial_balls_won_percentage
# 0                           1.43
# 1                           1.66
# 2                           1.77
# 3                           1.05
# 4                           1.78
# ..                           ...
# 277                         2.75
# 278                         2.80
# 279                         2.73
# 280                          NaN
# 281                          NaN
#
# [282 rows x 5 columns]

# %%
plt.figure(figsize=(15,15))
    
# number of variable
categories=list(kc)[1:]
N = len(categories)
 
# angle of each axis in the plot
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# spider plot
ax = plt.subplot(111, polar=True)
 
# axis to be on top
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# axe per variable
plt.xticks(angles[:-1], categories)
 
# ylabels
ax.set_rlabel_position(50)
plt.yticks(color="grey")
plt.ylim(0,2.8)
 

 
# Ind1
values=kc.loc[1].drop('player').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Onyinye Ndidi")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values=kc.loc[18].drop('player').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Declan Rice")
ax.fill(angles, values, 'r', alpha=0.1)

# Ind3
values=kc.loc[108].drop('player').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Jefferson Lerma")
ax.fill(angles, values, 'g', alpha=0.1)
 
# legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# title
plt.title('Radar Chart: Key Candidates Compared (percentages x3)', fontsize=30)

plt.show()
